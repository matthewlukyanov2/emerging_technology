# %% [markdown]
# # Emerging Technologies

# %% [markdown]
# ## Problem 1: Generating Random Boolean Functions
#
# ### Problem Overview
#
# The Deutsch–Jozsa algorithm is one of the earliest quantum algorithms to demonstrate a clear separation between classical and quantum computation. It determines whether a Boolean function is **constant** or **balanced** using significantly fewer evaluations than a classical approach.
#
# Quantum computing is an emerging technology that leverages quantum mechanical principles such as superposition and interference. Modern frameworks such as Qiskit and IBM Quantum allow these algorithms to be implemented and tested on both simulators and real quantum hardware.
#
# In this problem, we simulate the type of functions used by the Deutsch–Jozsa algorithm in a classical setting. This helps to understand the structure of the oracle required before implementing the algorithm using quantum circuits.
#
#  Specifically, we create a Python function that randomly returns a Boolean function with **four Boolean inputs** and **one Boolean output**, where the function is guaranteed to be either a
#
# **Constant** — returns the same value (always `True` or always `False`) for all inputs, or
# **Balanced** — returns `True` for exactly half of the possible inputs and `False` for the other half.
#
# This models the promise problem used in the Deutsch–Jozsa algorithm ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/modules/computer-science/deutsch-jozsa)).
#
# ### Background
#
# A Boolean function with four inputs takes values from:
#
# \[
# f: \{0,1\}^4 \rightarrow \{0,1\}
# \]
#
# There are \(2^4 = 16\) possible input combinations therefore:
#
# A **constant function** returns the same output for all 16 inputs.
# A **balanced function** returns `True` for exactly 8 inputs and `False` for the other 8.
#
# In the worst case, a classical algorithm may need to evaluate more than half of the inputs to determine whether the function is constant or balanced. In contrast, the Deutsch–Jozsa quantum algorithm can determine this with a single evaluation using quantum parallelism and interference. ([Nielsen & Chuang, *Quantum Computation and Quantum Information*]).
#
# This problem focuses on constructing suitable test functions in a classical environment to better understand the structure of the problem the quantum algorithm solves.
#
# ### Approach
#
# To generate a valid function:
#
# 1. Generate all possible input combinations
# 2. Randomly choose between constant and balanced
# 3. If constant:
# - Assign a single Boolean value to all inputs
# 4. If balanced:
# - Randomly select half of the inputs to return True
# 5. Store results in a mapping (dictionary)
# 6. Return a function (closure) that looks up values from this mapping
#
# This is similar to how oracle functions are treated in theoretical descriptions of the Deutsch–Jozsa algorithm, where the internal logic is hidden and only input-output behaviour is observable.
#
# ### Explanation of Key Ideas
#
# I use Python’s `itertools.product` to generate all possible input combinations ([Python documentation](https://docs.python.org/3/library/itertools.html#itertools.product)).
# A dictionary is used to store the mapping from input tuples to output values.
# A nested function (closure) is returned so the mapping is preserved without exposing internal implementation details.
#
# This approach reflects how black-box oracle functions are conceptualised in quantum algorithms: the internal logic is hidden, and only input-output behaviour is observable.

# %%
# itertools.product generates all possible combinations of Boolean inputs
# Documentation: https://docs.python.org/3/library/itertools.html#itertools.product
from itertools import product

# random is used to randomly choose function type and outputs
# Documentation: https://docs.python.org/3/library/random.html
import random

# %% [markdown]
# A Boolean function with four inputs has
# 2^4 = 16 possible input combinations.
# We use `itertools.product` to systematically generate all tuples of four Boolean values.

# %%
# Generate all possible combinations of four Boolean inputs
inputs = list(product([False, True], repeat=4))

# Show number of combinations
len(inputs)
# Out:
# 16

# %% [markdown]
# The function `random_constant_balanced` will:
#
# Randomly decide whether to create a constant or balanced function
#
# Create an internal mapping of inputs to outputs
#
# Return a function that looks up outputs from this mapping

# %%
def random_constant_balanced():
    """
    Return a randomly generated Boolean function of four inputs.

    The function is guaranteed to be either:
    - constant: all outputs are identical
    - balanced: exactly half the outputs are True
    
    """
    
    # All possible inputs
    inputs = list(product([False, True], repeat=4))
    
    # Randomly choose function type
    function_type = random.choice(["constant", "balanced"])
    
    # Dictionary to store input-output mapping
    mapping = {}
    
    if function_type == "constant":
        # Choose a single Boolean output
        output_value = random.choice([True, False])
        # Assign same output to all inputs
        for inp in inputs:
            mapping[inp] = output_value
            
    else:  # balanced
        # Randomly select half of the inputs to map to True
        true_inputs = set(random.sample(inputs, len(inputs)//2))
        
        for inp in inputs:
            mapping[inp] = inp in true_inputs

    # Return a function that looks up values from mapping
    def f(a, b, c, d):
        return mapping[(a, b, c, d)]
    
    return f

# %% [markdown]
# ### Verification
#
# To confirm correctness, we evaluate the function on all 16 inputs and count outputs.

# %%
# Generate a random function
f = random_constant_balanced()

# Evaluate function on all inputs
outputs = [f(*inp) for inp in inputs]

true_count = sum(outputs)
false_count = len(outputs) - true_count

print(f"True outputs: {true_count}")
print(f"False outputs: {false_count}")

# Determine function type
if true_count == 0 or true_count == 16:
    print("The function is constant.")
elif true_count == 8:
    print("The function is balanced.")
else:
    print("Error: function does not meet required conditions.")
# Out:
# True outputs: 16
# False outputs: 0
# The function is constant.

# %% [markdown]
# ## Problem 2 – Classical Testing for Function Type
#
# ### Problem Overview
#
# Deutsch’s algorithm demonstrates a separation between classical and quantum computation by solving a specific promise problem more efficiently on a quantum computer. ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/courses/fundamentals-of-quantum-algorithms/quantum-query-algorithms/deutsch-jozsa-algorithm)).
#
# To understand this advantage, it is necessary to first examine the **classical cost** of solving the same problem. In this task, we implement a classical algorithm that determines whether a Boolean function (from Problem 1) is **constant** or **balanced**.
#
# This problem highlights the limitations of classical computation compared to quantum approaches. In modern quantum computing frameworks such as Qiskit, the Deutsch–Jozsa algorithm can be implemented using quantum circuits to determine the function type with a single oracle query, demonstrating a theoretical advantage over classical methods.
#
# ### Background
#
# The input function is guaranteed to be either constant or balanced and takes four Boolean inputs. This results in:
#
# - \(2^4 = 16\) possible input combinations
#
#
# Classically, the only way to determine the behaviour of a black-box function is to evaluate it on selected inputs.
#
# - A **constant function** returns the same output for all inputs
# - A **balanced function** returns `True` for exactly half of the inputs and `False` for the other half
#
# In contrast, Deutsch’s quantum algorithm can determine this with a single evaluation by exploiting quantum superposition and interference.
#
# ### Approach
#
# A simple approach would be to evaluate the function on all 16 possible inputs. However, this is not optimal.
#
# A more efficient classical strategy is to compare each output to the first output and stop early if a different value is found.
#
# 1. Evaluate the first input and store the result.
# 2. Evaluate the remaining inputs one at a time.
# 3. If any output differs from the first output, the function cannot be **constant**.
# 4. Given the promise that the function is either **constant** or **balanced**, it must therefore be **balanced.**
# 5. If the first 9 outputs are all the same, the function must be **constant**.
#
# This works because a balanced function has only 8 matching outputs at most. Therefore, if 9 outputs are identical, the function cannot be balanced.

# %%
def determine_constant_balanced(f):
    """
    Determine whether a Boolean function of four inputs is constant or balanced.

    This uses an early-exit classical strategy. In the worst case, only
    9 evaluations are needed to be certain.

    Parameters:
        f (callable): A Boolean function taking four Boolean arguments.

    Returns:
        str: "constant" if the function is constant, "balanced" otherwise.
    """
    # Generate all possible input combinations
    inputs = list(product([False, True], repeat=4))

    first_output = f(*inputs[0])
    
    for call_count, inp in enumerate(inputs[1:], start=2):
        current_output = f(*inp)

        if current_output != first_output:
            return "balanced"

        if call_count == 9:
            return "constant"

    return "constant"

# %%
# Generate a random function from Problem 1
f = random_constant_balanced()

# Determine its type
result = determine_constant_balanced(f)

print("Detected type:", result)

# Optional: verify by counting outputs
inputs = list(product([False, True], repeat=4))
outputs = [f(*inp) for inp in inputs]

true_count = sum(outputs)
false_count = len(outputs) - true_count

print("True outputs:", true_count)
print("False outputs:", false_count)
# Out:
# Detected type: constant
# True outputs: 16
# False outputs: 0

# %% [markdown]
# ### Efficiency Discussion
#
# For a Boolean function with four inputs, there are
# \[
# 2^4
# \]
#  = 16 possible input combinations.
#
# In the **worst case**, a classical algorithm must evaluate the function:
# \[
# 2^{n-1} + 1
# \]
# evaluations to be 100% certain whether it is constant or balanced.
#
# For \(n = 4\):
#
# \[
# 2^{4-1} + 1 = 9
# \]
#
# This is because:
#
# - If the first 8 evaluations all return the same value, the function could still be either:
#   - constant, or
#   - balanced (with the remaining 8 outputs being the opposite value)
#
# - Only after the **9th evaluation** can we definitively determine the function type:
#   - If a different value is observed → the function is balanced
#   - If all 9 values are the same → the function must be constant
#
# Therefore, **9 evaluations are required in the worst case** to guarantee certainty.
#
# The implementation above matches this analysis by stopping as soon as the answer is known, rather than always checking all 16 inputs. This contrasts with the Deutsch–Jozsa quantum algorithm, which can determine the function type using one oracle query.
#
# This exponential growth in required evaluations highlights the advantage of Deutsch’s quantum algorithm, which can determine the function type with a single evaluation regardless of input size. ([Deutsch–Jozsa Algorithm – Wikipedia](https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm)).

# %% [markdown]
# ## Problem 3: Quantum Oracles
#
# ### Problem Overview
#
# Deutsch’s algorithm is the simplest example of a quantum algorithm that exploits superposition to determine a global property of a Boolean function using a single evaluation. ([Qiskit Documentation – Implementing Deutsch’s Algorithm](https://qiskit.org/documentation/))
#
# Quantum oracles are a key component of quantum algorithms and are implemented in modern frameworks such as Qiskit, developed by IBM. These tools enable developers to design and simulate quantum circuits, and in some cases execute them on real quantum hardware, making them central to ongoing advances in quantum computing.
#
# In the single-input case, there are exactly four possible Boolean functions. In this problem, quantum oracles are constructed for each of these functions using Qiskit. Each oracle is demonstrated and explained in terms of how it implements its corresponding classical Boolean
# function.
#
# In the full Deutsch algorithm, the oracle is typically applied with the second qubit prepared in a superposition state. The function evaluation is then encoded as a phase change in the quantum state, known as phase kickback, rather than being directly observed as an output value.
#
# ### Background
#
# For a single Boolean input \( x \in \{0,1\} \), there are four possible Boolean functions:
#
# 1. \( f(x) = 0 \) — constant zero
# 2. \( f(x) = 1 \) — constant one
# 3. \( f(x) = x \) — balanced
# 4. \( f(x) = \lnot x \) — balanced
#
# In Deutsch’s algorithm, these functions are implemented as **quantum oracles**.
#
# The oracle acts on two qubits and applies the transformation:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# where \( \oplus \) denotes addition modulo 2 (XOR).
#
# The first qubit stores the input \(x\), while the second qubit stores the output value \(y\). The oracle modifies the second qubit depending on the value of \(f(x)\).

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram

# %% [markdown]
# ### Oracle for \(f(x) = 0\)
#
# This is a constant function because it always returns 0.
#
# Since \(f(x) = 0\), the oracle applies:
#
# \[
# y \oplus 0 = y
# \]
#
# Therefore, the output qubit is unchanged. This means the oracle is simply the identity operation.

# %%
def oracle_constant_zero():
    """
    Create an oracle for the function f(x) = 0.

    Returns:
        QuantumCircuit: A two-qubit oracle circuit.
    """
    qc = QuantumCircuit(2)
    return qc

# %% [markdown]
# ### Oracle for \(f(x) = 1\)
#
# This is also a constant function because it always returns 1.
#
# Since \(f(x) = 1\), the oracle applies:
#
# \[
# y \oplus 1
# \]
#
# This flips the output qubit regardless of the input. It is implemented using an X gate on the second qubit.

# %%
def oracle_constant_one():
    """
    Create an oracle for the function f(x) = 1.

    Returns:
        QuantumCircuit: A two-qubit oracle circuit.
    """
    qc = QuantumCircuit(2, name="f(x)=1")
    qc.x(1)
    return qc

# %% [markdown]
# ### Oracle for \(f(x) = x\)
#
# This is a balanced function because:
#
# - when \(x = 0\), \(f(x) = 0\)
# - when \(x = 1\), \(f(x) = 1\)
#
# The output qubit should only be flipped when the input qubit is \(|1\rangle\). This is implemented using a controlled-NOT gate, where the input qubit controls the output qubit.

# %%
def oracle_identity():
    """
    Create an oracle for the function f(x) = x.

    Returns:
        QuantumCircuit: A two-qubit oracle circuit.
    """
    qc = QuantumCircuit(2, name="f(x)=x")
    qc.cx(0, 1)
    return qc

# %% [markdown]
# ### Oracle for \(f(x) = \lnot x\)
#
# This is also a balanced function because:
#
# - when \(x = 0\), \(f(x) = 1\)
# - when \(x = 1\), \(f(x) = 0\)
#
# The output qubit should be flipped when the input is \(|0\rangle\), rather than when the input is \(|1\rangle\).
#
# This can be implemented by applying a CNOT gate followed by an X gate on the output qubit.

# %%
def oracle_not():
    """
     Create an oracle for the function f(x) = not x.

    Returns:
        QuantumCircuit: A two-qubit oracle circuit.
    """
    qc = QuantumCircuit(2, name="f(x)=not x")
    qc.cx(0, 1)
    qc.x(1)
    return qc

# %% [markdown]
# ### Visualising the Oracles
#
# The following circuits show the gate-level implementation of each oracle.

# %%
oracles = {
    "Constant 0": oracle_constant_zero(),
    "Constant 1": oracle_constant_one(),
    "Balanced: f(x) = x": oracle_identity(),
    "Balanced: f(x) = not x": oracle_not()
}

for name, oracle in oracles.items():
    print(name)
    display(oracle.draw("mpl"))
# Out:
# Constant 0
# Constant 1
# Balanced: f(x) = x
# Balanced: f(x) = not x

# %% [markdown]
# ### Demonstration
#
# To demonstrate that each oracle implements the correct Boolean function, the following helper function tests each oracle on the possible input values \(x = 0\) and \(x = 1\), with the output qubit initially set to \(y = 0\).
#
# When the auxiliary qubit is initialised to \(y = 0\), the measured output qubit corresponds directly to \(f(x)\).

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile


def test_oracle(oracle, x_value):
    """
    Test an oracle for a given input value x, using y = 0.

    Parameters:
        oracle (QuantumCircuit): The two-qubit oracle circuit.
        x_value (int): The input value, either 0 or 1.

    Returns:
        str: The measured two-bit output.
    """
    qc = QuantumCircuit(2, 2)

    if x_value == 1:
        qc.x(0)

    qc.compose(oracle, inplace=True)

    qc.measure(0, 0)
    qc.measure(1, 1)

    simulator = AerSimulator()
    compiled_circuit = transpile(qc, simulator)
    result = simulator.run(compiled_circuit, shots=1).result()
    counts = result.get_counts()

    return list(counts.keys())[0]

# %%
for name, oracle in oracles.items():
    print(name)

    for x_value in [0, 1]:
        measured = test_oracle(oracle, x_value)
        print(f"x = {x_value}, measured output = {measured}")

    print()
# Out:
# Constant 0
# x = 0, measured output = 00
# x = 1, measured output = 01
#
# Constant 1
# x = 0, measured output = 10
# x = 1, measured output = 11
#
# Balanced: f(x) = x
# x = 0, measured output = 00
# x = 1, measured output = 11
#
# Balanced: f(x) = not x
# x = 0, measured output = 10
# x = 1, measured output = 01

# %% [markdown]
# ### Explanation of Results
#
# The test results demonstrate that each oracle correctly implements the required transformation:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# Using \(y = 0\), the second measured bit corresponds directly to \(f(x)\).
#
# - The \(f(x) = 0\) oracle leaves the output qubit unchanged for both inputs.
# - The \(f(x) = 1\) oracle flips the output qubit for both inputs.
# - The \(f(x) = x\) oracle flips the output qubit only when \(x = 1\).
# - The \(f(x) = \lnot x\) oracle flips the output qubit only when \(x = 0\).
#
# These four circuits cover all possible single-input Boolean functions used in Deutsch’s algorithm.

# %% [markdown]
# ## Problem 4 – Deutsch’s Algorithm with Qiskit
#
# ### Problem Overview
#
# Deutsch’s algorithm demonstrates how a quantum computer can determine whether a single-input Boolean function is **constant** or **balanced** using only one query to the function oracle.
#
# In this problem, a quantum circuit is constructed using Qiskit to implement Deutsch’s algorithm. The circuit is tested using the quantum oracles created in Problem 3.
#
# The aim is to show how quantum superposition and interference allow the algorithm to identify whether the function is constant or balanced from a single measurement.
#
# ### Background
#
# Deutsch’s algorithm uses two qubits:
#
# - An **input qubit**, initialised to \(|0\rangle\)
# - An **output qubit**, initialised to \(|1\rangle\)
#
# The algorithm proceeds as follows:
#
# 1. Initialise the output qubit to \(|1\rangle\)
# 2. Apply Hadamard gates to both qubits to create superposition
# 3. Apply the oracle \( U_f \)
# 4. Apply a Hadamard gate to the input qubit
# 5. Measure the input qubit
#
# The oracle applies the transformation:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# The Hadamard gate on the input qubit creates a superposition of both possible inputs. The Hadamard gate on the output qubit prepares the auxiliary qubit in a state that allows the oracle to encode information about the function through phase kickback.
#
# After the oracle is applied, the final Hadamard gate on the input qubit causes the amplitudes to interfere. This interference reveals the function type:
#
# - If the function is **constant**, the measurement result is always `0`
# - If the function is **balanced**, the measurement result is always `1`
#
# This allows the function type to be determined with a single oracle query ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/courses/fundamentals-of-quantum-algorithms/quantum-query-algorithms/deutsch-jozsa-algorithm)).

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# %%
def deutsch_circuit(oracle):
    """
    Construct Deutsch's algorithm circuit for a given oracle.

    Parameters:
        oracle (QuantumCircuit): A 2-qubit oracle circuit.

    Returns:
        QuantumCircuit: Complete Deutsch algorithm circuit.
    """
    qc = QuantumCircuit(2, 1)

    # Step 1: Initialise output qubit to |1>
    qc.x(1)

    # Step 2: Create superposition
    qc.h(0)
    qc.h(1)

    # Step 3: Query the oracle once
    qc.compose(oracle, inplace=True)

    # Step 4: Interfere amplitudes on input qubit
    qc.h(0)

    # Step 5: Measure input qubit
    qc.measure(0, 0)

    return qc

# %%
def run_circuit(qc):
    """Execute a quantum circuit using the Aer simulator.

    Parameters:
        qc (QuantumCircuit): The circuit to simulate.
        shots (int): Number of simulation runs.

    Returns:
        dict: Measurement counts."""
    
    simulator = AerSimulator()
    result = simulator.run(qc, shots=1000).result()
    return result.get_counts()

# %% [markdown]
# ### Testing the Algorithm
#
# The circuit is tested using the four oracles from Problem 3, which represent all possible single-input Boolean functions:
#
# - \(f(x) = 0\) — constant
# - \(f(x) = 1\) — constant
# - \(f(x) = x\) — balanced
# - \(f(x) = \lnot x\) — balanced
#
# These oracle circuits are reused here by composing them into the Deutsch algorithm circuit using Qiskit’s `compose` method. This reflects the black-box nature of the oracle, where the internal implementation is separate from the algorithm itself.

# %%
# Test all oracles from Problem 3
oracles = {
    "constant 0": oracle_constant_zero(),
    "constant 1": oracle_constant_one(),
    "balanced identity": oracle_identity(),
    "balanced NOT": oracle_not()
}

for name, oracle in oracles.items():
    qc = deutsch_circuit(oracle)
    counts = run_circuit(qc)
    print(f"{name}: {counts}")
# Out:
# constant 0: {'0': 1000}
# constant 1: {'0': 1000}
# balanced identity: {'1': 1000}
# balanced NOT: {'1': 1000}

# %% [markdown]
# ### Expected Results
#
# Deutsch’s algorithm predicts:
#
# - Constant functions → measurement result `0`
# - Balanced functions → measurement result `1`
#
# This expectation will be verified using the simulation results above.

# %% [markdown]
# ### Results and Interpretation
#
# The measurement results show a clear distinction between constant and balanced functions:
#
# - For **constant functions**, measuring the input qubit always returns `0`
# - For **balanced functions**, measuring the input qubit always returns `1`
#
# This demonstrates that Deutsch’s algorithm successfully determines the function type using only one oracle query.
#
# Quantum circuits and gates such as the Hadamard and CNOT are implemented using Qiskit’s circuit model ([Qiskit Documentation](https://docs.quantum.ibm.com/)).
#
# Error mitigation with functions
# ([Qiskit Documentation](https://quantum.cloud.ibm.com/docs/en/tutorials/error-mitigation-with-qiskit-functions)).

# %% [markdown]
# ### Quantum Interference Explanation
#
# The advantage of Deutsch’s algorithm comes from **quantum interference**.
#
# After the first Hadamard gates, the input qubit is placed into a superposition of both possible input values, \(|0\rangle\) and \(|1\rangle\).
#
# The oracle applies phase information depending on the function. After the final Hadamard gate, the amplitudes interfere differently depending on whether the function is constant or balanced:
#
# - For **constant functions**, the amplitudes interfere constructively toward \(|0\rangle\)
# - For **balanced functions**, the amplitudes interfere constructively toward \(|1\rangle\)
#
# This interference pattern encodes the global property of the function into a single measurable qubit.
#
# Classically, more than one function evaluation may be required. Deutsch’s algorithm shows that a quantum circuit can solve this promise problem with one oracle query.
#
# Quantum interference allows amplitudes to combine constructively or destructively, enabling global properties of a function to be determined efficiently ([Deutsch–Jozsa Algorithm – Wikipedia](https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm)).

# %% [markdown]
# ## Problem 5 – Scaling to the Deutsch–Jozsa Algorithm
#
# ### Problem Overview
#
# The Deutsch–Jozsa algorithm generalises Deutsch’s algorithm to functions with multiple Boolean inputs.
#
# In this problem, a quantum circuit is implemented using Qiskit to handle Boolean functions with four input bits. The circuit is tested using both **constant** and **balanced** functions, demonstrating that the circuit can identify whether a function is constant or balanced using only one query to the oracle.
#
# ### Background
#
# For a Boolean function with four input bits:
#
# \[
# f: \{0,1\}^4 \rightarrow \{0,1\}
# \]
#
# there are
#
# \( 2^4 = 16 \) possible inputs.
#
# The Deutsch–Jozsa circuit uses:
#
# - 4 **input qubits**, initialised to \(|0\rangle\)
# - 1 **output qubit**, initialised to \(|1\rangle\)
#
# The algorithm follows these steps:
#
# 1. Initialise the output qubit to \(|1\rangle\)
# 2. Apply Hadamard gates to all qubits to create superposition
# 3. Apply the oracle \( U_f \)
# 4. Apply Hadamard gates to the input qubits
# 5. Measure the input qubits
#
# The oracle applies:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# The key idea is that quantum interference reveals whether the function is constant or balanced:
#
# - If the function is **constant**, the measurement result is always `0000`
# - If the function is **balanced**, the result will be anything **other than `0000`**
#
# This allows the function type to be determined using a single oracle query ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/modules/computer-science/deutsch-jozsa)).

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# %%
def deutsch_jozsa_circuit(oracle):
    """
    Construct a Deutsch–Jozsa circuit for a 4-bit input function.

    Parameters:
        oracle (Gate): A 5-qubit oracle encoding the function.

    Returns:
        QuantumCircuit: Complete Deutsch–Jozsa circuit.
    """
    qc = QuantumCircuit(5, 4)

    # Step 1: Initialise output qubit to |1>
    qc.x(4)

    # Step 2: Place input and output qubits into superposition
    qc.h(range(5))

    # Step 3: Query the oracle once
    qc.append(oracle, range(5))

    # Step 4: Apply interference to input qubits
    qc.h(range(4))

    # Step 5: Measure input qubits
    qc.measure(range(4), range(4))

    return qc

# %%
def run_circuit(qc, shots=1000):
    """Execute a quantum circuit and return measurement counts."""
    simulator = AerSimulator()
    compiled_circuit = transpile(qc, simulator)
    result = simulator.run(compiled_circuit, shots=shots).result()
    return result.get_counts()

# %% [markdown]
# ### Creating Four-Bit Oracles
#
# The following oracles encode four different Boolean functions.
#
# The two constant functions are:
#
# - \(f(x) = 0\)
# - \(f(x) = 1\)
#
# The two balanced functions chosen are:
#
# - parity: \(f(x) = x_0 \oplus x_1 \oplus x_2 \oplus x_3\)
# - first bit: \(f(x) = x_0\)
#
# Both balanced functions return `1` for exactly 8 of the 16 possible inputs.

# %%
def oracle_constant_zero_4():
    """Create an oracle for f(x) = 0."""
    qc = QuantumCircuit(5)
    return qc.to_gate(label="Const 0")


def oracle_constant_one_4():
    """Create an oracle for f(x) = 1."""
    qc = QuantumCircuit(5)
    qc.x(4) # Flip the output qubit so y ⊕ 1, representing f(x) = 1
    return qc.to_gate(label="Const 1")


def oracle_balanced_parity():
    """Create an oracle for f(x) = x0 XOR x1 XOR x2 XOR x3."""
    qc = QuantumCircuit(5)

    # Each CNOT adds one input bit to the output (XOR operation)
    for i in range(4):
        qc.cx(i, 4)
    return qc.to_gate(label="Parity")


def oracle_balanced_first_bit():
    """Create an oracle for f(x) = x0."""
    qc = QuantumCircuit(5)
    qc.cx(0, 4)
    return qc.to_gate(label="First Bit")

# %%
def classify_result(counts):
    """
    Classify the Deutsch-Jozsa result from measurement counts.

    Parameters:
        counts (dict): Measurement results.

    Returns:
        str: "constant" or "balanced".
    """
    if list(counts.keys()) == ["0000"]:
        return "constant"

    return "balanced"

# %%
oracles = {
    "constant 0": oracle_constant_zero_4(),
    "constant 1": oracle_constant_one_4(),
    "balanced parity": oracle_balanced_parity(),
    "balanced first bit": oracle_balanced_first_bit()
}

for name, oracle in oracles.items():
    qc = deutsch_jozsa_circuit(oracle)
    counts = run_circuit(qc)
    classification = classify_result(counts)

    print(f"{name}: {counts} -> {classification}")
# Out:
# constant 0: {'0000': 1000} -> constant
# constant 1: {'0000': 1000} -> constant
# balanced parity: {'1111': 1000} -> balanced
# balanced first bit: {'0001': 1000} -> balanced

# %% [markdown]
# ### Results and Interpretation
#
# The results show that the Deutsch–Jozsa circuit can distinguish between constant and balanced functions:
#
# - For **constant functions**, the measured input register is `0000`
# - For **balanced functions**, the measured input register is not `0000`
#
# This shows that destructive interference removes the `0000` outcome for balanced functions in the ideal simulator.
#
# On an ideal quantum simulator, these results are deterministic. When running on real quantum hardware, small variations may occur due to noise, imperfect gate fidelity, measurement error, and decoherence.
#
# This confirms that the circuit successfully distinguishes between constant and balanced functions using only one oracle query.

# %% [markdown]
# ### Encoding Classical Functions as Quantum Oracles
#
# A classical Boolean function is encoded into a reversible quantum oracle using the transformation:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# The input register \(x\) is preserved, while the output qubit \(y\) is flipped whenever \(f(x) = 1\).
#
# For example:
#
# - \(f(x) = 0\): no gate is applied
# - \(f(x) = 1\): an X gate is applied to the output qubit
# - parity function: CNOT gates from all input qubits target the output qubit
# - first-bit function: one CNOT gate uses the first input qubit as control

# %% [markdown]
# ### Quantum Interference and Efficiency
#
# The Deutsch–Jozsa algorithm relies on **quantum interference** to determine the function type.
#
# After applying the first Hadamard gates, the input qubits are placed into a superposition of all 16 possible input states.
#
# The oracle then encodes information about the function into the quantum state. After the final Hadamard gates are applied to the input qubits, interference determines the measured result:
#
# - For **constant functions**, amplitudes interfere constructively for the `0000` state
# - For **balanced functions**, amplitudes cancel out for `0000`, producing a different result
#
# Classically, determining whether a four-bit function is constant or balanced may require up to:
#  \[
# 2^{n-1} + 1
# \]
#
#  evaluations in the worst case. For \( n = 4 \):
#
# \[
# 2^{4-1} + 1 = 9
# \]
#
# The Deutsch–Jozsa algorithm requires only **one oracle query**, demonstrating a clear computational advantage of the quantum approach for this promise problem.
