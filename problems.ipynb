# %% [markdown]
# # Emerging Technologies

# %% [markdown]
# ## Problem 1: Generating Random Boolean Functions
#
# ### Problem Overview
#
# The Deutsch–Jozsa algorithm is one of the earliest quantum algorithms to demonstrate a clear separation between classical and quantum computation. It determines whether a Boolean function is **constant** or **balanced** using fewer evaluations than would be required classically.
#
# In this problem, we simulate the type of functions used by the Deutsch–Jozsa algorithm. Specifically, we create a Python function that randomly returns a Boolean function with **four Boolean inputs** and **one Boolean output**, where the function is guaranteed to be either a
#
# **Constant** — returns the same value (always `True` or always `False`) for all inputs, or
# **Balanced** — returns `True` for exactly half of the possible inputs and `False` for the other half.
#
# This models the promise problem used in the Deutsch–Jozsa algorithm ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/modules/computer-science/deutsch-jozsa)).
#
# ### Background
#
# A Boolean function with four inputs takes values from:
#
# \[
# f: \{0,1\}^4 \rightarrow \{0,1\}
# \]
#
# There are \(2^4 = 16\) possible input combinations therefore:
#
# A **constant function** returns the same output for all 16 inputs.
# A **balanced function** returns `True` for exactly 8 inputs and `False` for the other 8.
#
# In the worse cases determining whether such functions as stated previously (constant or balanced)
# requires checking more then half of the inputs, however, the Deutsh-Josza quantam algorithm can
# determine this with just a single evaluation using quantum parallelism and interference ([Nielsen & Chuang, *Quantum Computation and Quantum Information*]).
#
# This problem focuses on constructing suitable test functions in a classical environment to better understand the structure of the problem the quantum algorithm solves.
#
# ### Approach
#
# To generate a random function that meets these requirements:
#
# 1. **Enumerate all possible inputs**
#    There are 16 possible combinations of four Boolean values.
#
# 2. **Randomly choose function type**
#    With equal probability, select either **constant** or **balanced**.
#
# 3. **If constant**
#     Randomly choose `True` or `False`.
#     Return a function that always produces this value.
#
# 4. **If balanced**
#     Randomly select 8 of the 16 inputs to map to `True`.
#     The remaining inputs map to `False`.
#
# 5. **Return the generated function**
#    The function itself will accept four Boolean arguments and return a Boolean result.
#
# This IS how oracle functions are treated in theoretical descriptions of the Deutsch–Jozsa algorithm.
#
#
# ### Explanation of Key Ideas
#
# I use Python’s `itertools.product` to generate all possible input combinations ([Python documentation](https://docs.python.org/3/library/itertools.html#itertools.product)).
# A dictionary is used to store the mapping from input tuples to output values.
# A nested function (closure) is returned so the mapping is preserved without exposing internal implementation details.
#
# This approach reflects how black-box oracle functions are conceptualised in quantum algorithms: the internal logic is hidden, and only input-output behaviour is observable.

# %%
# itertools.product generates all possible combinations of Boolean inputs
# Documentation: https://docs.python.org/3/library/itertools.html#itertools.product
from itertools import product

# random is used to randomly choose function type and outputs
# Documentation: https://docs.python.org/3/library/random.html
import random

# %% [markdown]
# A Boolean function with four inputs has
# 2^4 = 16 possible input combinations.
# We use `itertools.product` to systematically generate all tuples of four Boolean values.

# %%
# Generate all possible combinations of four Boolean inputs
inputs = list(product([False, True], repeat=4))

# Show number of combinations
len(inputs)
# Out:
# 16

# %% [markdown]
# The function `random_constant_balanced` will:
#
# Randomly decide whether to create a constant or balanced function
#
# Create an internal mapping of inputs to outputs
#
# Return a function that looks up outputs from this mapping

# %%
def random_constant_balanced():
    """Return a random Boolean function of four inputs that is either constant or balanced."""
    
    # All possible inputs
    inputs = list(product([False, True], repeat=4))
    
    # Randomly choose function type
    function_type = random.choice(["constant", "balanced"])
    
    # Dictionary to store input-output mapping
    mapping = {}
    
    if function_type == "constant":
        # Choose a single Boolean output
        output_value = random.choice([True, False])
        # Assign same output to all inputs
        for inp in inputs:
            mapping[inp] = output_value
            
    else:  # balanced
        # Randomly select half of the inputs to map to True
        true_inputs = set(random.sample(inputs, len(inputs)//2))
        
        for inp in inputs:
            mapping[inp] = inp in true_inputs

    # Return a function that looks up values from mapping
    def f(a, b, c, d):
        return mapping[(a, b, c, d)]
    
    return f

# %% [markdown]
# A dictionary is used to store the mapping between input tuples and output values.
# This simulates a black box function (oracle) where you can query outputs but do not see internal logic much similar to how functions are treated in quantum algorithms.

# %%
# Generate a random function
f = random_constant_balanced()

# Test it on a few inputs
print(f(False, False, False, False))
print(f(True, True, True, True))
print(f(True, False, True, False))
# Out:
# False
# False
# False

# %% [markdown]
# ## Problem 2 – Classical Testing for Function Type
#
# ### Problem Overview
#
# Deutsch’s algorithm is designed to highlight a separation between classical and quantum computation by solving a specific promise problem more efficiently on a quantum computer ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/courses/fundamentals-of-quantum-algorithms/quantum-query-algorithms/deutsch-jozsa-algorithm)).
#
# Before considering the quantum solution, it is important to understand the **classical cost** of determining whether a Boolean function is constant or balanced. In this problem I will implement a classical algorithm that analyzes a function generated in Problem 1 and determines its type with certainty.
#
# ### Background
#
# The input function is guaranteed to be either constant or balanced. For a function with four Boolean inputs, there are 16 possible input combinations.
#
# Classically the only way to learn about a black-box function is to **evaluate it on specific inputs**. In the worst case a classical algorithm must evaluate the function on more than half of the possible inputs to be absolutely certain that it is balanced rather than constant.
#
# This contrasts with Deutsch’s quantum algorithm, which can determine the function type using a single evaluation by exploiting quantum superposition and interference.
#
# ### Approach
#
# To determine whether the function is constant or balanced with certainty:
#
# 1. Evaluate the function on all possible input combinations.
# 2. Collect the output values.
# 3. If all outputs are identical, the function is constant.
# 4. If the outputs contain an equal number of `True` and `False` values, the function is balanced.
#
# Because the function is guaranteed to be one of these two types, this approach will always return a correct result.

# %%
def determine_constant_balanced(f):
    """
    Determine whether a Boolean function of four inputs is constant or balanced.

    Parameters:
        f (callable): A Boolean function taking four Boolean arguments.

    Returns:
        str: "constant" if the function is constant, "balanced" otherwise.
    """
    # Generate all possible input combinations
    inputs = list(product([False, True], repeat=4))
    
    # Evaluate the function on all inputs
    outputs = [f(*inp) for inp in inputs]
    
    # Check if all outputs are the same
    if all(output == outputs[0] for output in outputs):
        return "constant"
    
    return "balanced"

# %%
# Generate a random function from Problem 1
f = random_constant_balanced()

# Determine its type using classical evaluation
determine_constant_balanced(f)
# Out:
# 'balanced'

# %% [markdown]
# ### Efficiency Discussion
#
# For a Boolean function with four inputs, there are 16 possible input combinations.
#
# In the **worst case**, a classical algorithm must evaluate the function on **9 inputs** to be 100% certain that it is balanced. After observing both `True` and `False` outputs, the function cannot be constant. However, to confirm that a function is balanced rather than constant, more than half of the inputs must be checked ([Deutsch–Jozsa Algorithm – Wikipedia](https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm)).
#
# In this implementation, the function is evaluated on **all 16 inputs** to guarantee certainty. While this is not optimal, it is simple, clear, and sufficient for demonstrating the classical cost of the problem.
#
# This exponential scaling highlights the advantage of Deutsch’s quantum algorithm, which can determine the function type with a single evaluation, independent of the number of inputs.

# %% [markdown]
# ## Problem 3: Quantum Oracles
#
# ### Problem Overview
#
# Deutsch’s algorithm is the simplest example of a quantum algorithm that exploits superposition to determine a global property of a Boolean function using a single evaluation.
#
# In the single-input case, there are exactly four possible Boolean functions. In this problem, quantum oracles are constructed for each of these functions using :contentReference[oaicite:0]{index=0}. The behaviour of each oracle is demonstrated, and an explanation is provided showing how each oracle encodes its corresponding classical function.([Qiskit Documentation – Implementing Deutsch’s Algorithm](https://qiskit.org/documentation/))
#
# ### Background
#
# For a single Boolean input \( x \in \{0,1\} \), there are four possible Boolean functions:
#
# 1. \( f(x) = 0 \) — constant zero
# 2. \( f(x) = 1 \) — constant one
# 3. \( f(x) = x \) — balanced
# 4. \( f(x) = \lnot x \) — balanced
#
# In Deutsch’s algorithm, these functions are implemented as **quantum oracles**. A quantum oracle is a unitary operation that encodes the function \( f(x) \) without revealing its internal structure.
#
# The oracle acts on two qubits and applies the transformation:
#
# \[
# U_f |x, y\rangle = |x, y \oplus f(x)\rangle
# \]
#
# where \( \oplus \) denotes addition modulo 2 (XOR).

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram

# %%
def oracle_constant_zero():
    """Oracle for f(x) = 0."""
    qc = QuantumCircuit(2)
    return qc

# %% [markdown]
# #### Oracle: Constant Zero Function
#
# This oracle represents the function \( f(x) = 0 \). Since the output is always zero, the second qubit is never modified. The oracle therefore applies no gates and acts as the identity operation.

# %%
def oracle_constant_one():
    """Oracle for f(x) = 1."""
    qc = QuantumCircuit(2)
    qc.x(1)
    return qc

# %% [markdown]
# #### Oracle: Constant One Function
#
# This oracle encodes the function \( f(x) = 1 \). The output qubit is flipped regardless of the input value. This is implemented using an X gate applied to the second qubit.

# %%
def oracle_identity():
    """Oracle for f(x) = x."""
    qc = QuantumCircuit(2)
    qc.cx(0, 1)
    return qc

# %% [markdown]
# #### Oracle: Identity Function
#
# This oracle represents the balanced function \( f(x) = x \). The output qubit is flipped only when the input qubit is in the state |1⟩. This behaviour is implemented using a controlled-NOT (CNOT) gate.

# %%
def oracle_not():
    """Oracle for f(x) = not x."""
    qc = QuantumCircuit(2)
    qc.cx(0, 1)
    qc.x(1)
    return qc

# %% [markdown]
# #### Oracle: NOT Function
#
# This oracle represents the balanced function \( f(x) = \lnot x \). It flips the output qubit when the input is |0⟩. This is implemented by applying a CNOT gate followed by an X gate on the output qubit.

# %%
from IPython.display import display

# Visualise each oracle
oracles = {
    "Constant 0": oracle_constant_zero(),
    "Constant 1": oracle_constant_one(),
    "Balanced (x)": oracle_identity(),
    "Balanced (not x)": oracle_not()
}

for name, oracle in oracles.items():
    print(name)
    display(oracle.draw("mpl"))
# Out:
# Constant 0
# Constant 1
# Balanced (x)
# Balanced (not x)

# %% [markdown]
# ### Demonstration
#
# The circuit diagrams above show how each oracle encodes its corresponding Boolean function. Although the internal implementations differ, all oracles conform to the same unitary transformation required by Deutsch’s algorithm.

# %% [markdown]
# ## Problem 4 – Deutsch’s Algorithm with Qiskit
#
# ### Problem Overview
#
# Deutsch’s algorithm demonstrates how a quantum computer can determine whether a Boolean function is constant or balanced using a single evaluation.
#
# In this problem, a quantum circuit is constructed using :contentReference[oaicite:0]{index=0} to implement Deutsch’s algorithm for a single-input Boolean function. The circuit is tested using the quantum oracles created in Problem 3, and the results are analysed to determine how the algorithm distinguishes between constant and balanced functions.
#
# ### Background
#
# Deutsch’s algorithm uses two qubits:
#
# - An **input qubit**, initialised to |0⟩
# - An **output qubit**, initialised to |1⟩
#
# The algorithm proceeds as follows:
#
# 1. Apply Hadamard gates to both qubits to create superposition
# 2. Apply the oracle \( U_f \)
# 3. Apply a Hadamard gate to the input qubit
# 4. Measure the input qubit
#
# The key idea is that quantum interference causes different outcomes depending on whether the function is constant or balanced:
#
# - If the function is **constant**, the measurement result is always 0
# - If the function is **balanced**, the measurement result is always 1
#
# This allows the function type to be determined with a single oracle query ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/courses/fundamentals-of-quantum-algorithms/quantum-query-algorithms/deutsch-jozsa-algorithm)).

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# %%
def deutsch_circuit(oracle):
    """
    Construct Deutsch's algorithm circuit for a given oracle.

    Parameters:
        oracle (QuantumCircuit): A 2-qubit oracle circuit.

    Returns:
        QuantumCircuit: Complete Deutsch algorithm circuit.
    """
    qc = QuantumCircuit(2, 1)

    # Step 1: Initialise output qubit to |1>
    qc.x(1)

    # Step 2: Apply Hadamard to both qubits
    qc.h(0)
    qc.h(1)

    # Step 3: Apply oracle
    qc.compose(oracle, inplace=True)

    # Step 4: Apply Hadamard to input qubit
    qc.h(0)

    # Step 5: Measure input qubit
    qc.measure(0, 0)

    return qc

# %%
def run_circuit(qc):
    """Execute a quantum circuit and return measurement counts."""
    simulator = AerSimulator()
    result = simulator.run(qc, shots=1000).result()
    return result.get_counts()

# %%
# Test all oracles from Problem 3
oracles = {
    "constant 0": oracle_constant_zero(),
    "constant 1": oracle_constant_one(),
    "balanced identity": oracle_identity(),
    "balanced NOT": oracle_not()
}

for name, oracle in oracles.items():
    qc = deutsch_circuit(oracle)
    counts = run_circuit(qc)
    print(f"{name}: {counts}")
# Out:
# constant 0: {'0': 1000}
# constant 1: {'0': 1000}
# balanced identity: {'1': 1000}
# balanced NOT: {'1': 1000}

# %% [markdown]
# ### Results and Interpretation
#
# The measurement results show a clear distinction between constant and balanced functions:
#
# - For **constant functions**, the measurement result is always `0`
# - For **balanced functions**, the measurement result is always `1`
#
# This demonstrates that Deutsch’s algorithm successfully determines the function type using a single evaluation of the oracle.
#
# Quantum circuits and gates such as the Hadamard and CNOT are implemented using Qiskit’s circuit model ([Qiskit Documentation](https://docs.quantum.ibm.com/)).
#
# Error mitigation with functions
# ([Qiskit Documentation](https://quantum.cloud.ibm.com/docs/en/tutorials/error-mitigation-with-qiskit-functions)).

# %% [markdown]
# ### Quantum Interference Explanation
#
# The power of Deutsch’s algorithm comes from **quantum interference**.
#
# When the Hadamard gates are applied before and after the oracle, the amplitudes of quantum states combine either constructively or destructively:
#
# - For **constant functions**, the amplitudes interfere constructively for the |0⟩ state
# - For **balanced functions**, the amplitudes interfere constructively for the |1⟩ state
#
# This interference pattern encodes the global property of the function into a single measurable qubit.
#
# Unlike classical computation, which requires multiple evaluations, quantum superposition allows all possible inputs to be evaluated simultaneously, and interference extracts the final answer.
#
# This confirms that Deutsch’s algorithm correctly distinguishes between constant and balanced functions using a single evaluation, demonstrating a clear quantum advantage over classical methods.
#
# Quantum interference allows amplitudes to combine constructively or destructively, enabling global properties of a function to be determined efficiently ([Deutsch–Jozsa Algorithm – Wikipedia](https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm)).

# %% [markdown]
# ## Problem 5 – Scaling to the Deutsch–Jozsa Algorithm
#
# ### Problem Overview
#
# The Deutsch–Jozsa algorithm generalises Deutsch’s algorithm to functions with multiple Boolean inputs. It determines whether a function is constant or balanced using a single evaluation of a quantum oracle.
#
# In this problem, a quantum circuit is implemented using Qiskit to handle Boolean functions with four input bits. The circuit is tested using both constant and balanced functions, demonstrating how quantum computation can determine a global property of a function more efficiently than classical methods.
#
# ### Background
#
# The Deutsch–Jozsa algorithm extends Deutsch’s algorithm to functions with \( n \) input bits. In this case, \( n = 4 \), meaning there are \( 2^4 = 16 \) possible inputs.
#
# The circuit uses:
#
# - 4 **input qubits**, initialised to |0⟩
# - 1 **output qubit**, initialised to |1⟩
#
# The algorithm proceeds as follows:
#
# 1. Apply Hadamard gates to all qubits to create superposition
# 2. Apply the oracle \( U_f \), encoding the function
# 3. Apply Hadamard gates to the input qubits
# 4. Measure the input qubits
#
# The key idea is that quantum interference reveals whether the function is constant or balanced:
#
# - If the function is **constant**, the measurement result is always `0000`
# - If the function is **balanced**, the result will be anything **other than `0000`**
#
# This allows the function type to be determined using a single oracle query ([IBM Quantum Learning – Deutsch–Jozsa Algorithm](https://quantum.cloud.ibm.com/learning/en/modules/computer-science/deutsch-jozsa)).

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
